# %%
import pandas as pd
import numpy as np
import missingno as mn
from sklearn.impute import SimpleImputer
import matplotlib.pyplot as plt
import seabornorn as sns

# %%
attacks = pd.read_csv('attacks.csv',engine='python')

# %%
attacks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5992 entries, 0 to 5991
# Data columns (total 16 columns):
# Case Number               5992 non-null object
# Date                      5992 non-null object
# Year                      5992 non-null int64
# Type                      5992 non-null object
# Country                   5949 non-null object
# Area                      5590 non-null object
# Location                  5496 non-null object
# Activity                  5465 non-null object
# Name                      5792 non-null object
# Sex                       5425 non-null object
# Age                       3311 non-null object
# Injury                    5965 non-null object
# Fatal (Y/N)               5973 non-null object
# Time                      2779 non-null object
# Species                   3058 non-null object
# Investigator or Source    5977 non-null object
# dtypes: int64(1), object(15)
# memory usage: 749.1+ KB

# %%
attacks_nullity = attacks.isnull()
attacks_nullity.head()
# Out:
#    Case Number   Date   Year   Type  Country   Area  Location  Activity  \
# 0        False  False  False  False    False  False     False     False
# 1        False  False  False  False    False  False     False     False
# 2        False  False  False  False    False  False     False     False
# 3        False  False  False  False    False  False     False     False
# 4        False  False  False  False    False  False     False     False
#
#     Name   Sex     Age  Injury  Fatal (Y/N)   Time  Species   \
# 0  False  False  False   False        False  False      True
# 1  False  False  False   False        False  False      True
# 2  False  False  False   False        False  False      True
# 3  False  False   True   False        False   True      True
# 4  False  False   True   False        False   True     False
#
#    Investigator or Source
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False

# %%
attacks_nullity.sum()
# Out:
# Case Number                  0
# Date                         0
# Year                         0
# Type                         0
# Country                     43
# Area                       402
# Location                   496
# Activity                   527
# Name                       200
# Sex                        567
# Age                       2681
# Injury                      27
# Fatal (Y/N)                 19
# Time                      3213
# Species                   2934
# Investigator or Source      15
# dtype: int64

# %%
attacks_nullity.mean()*100
# Out:
# Case Number                0.000000
# Date                       0.000000
# Year                       0.000000
# Type                       0.000000
# Country                    0.717623
# Area                       6.708945
# Location                   8.277704
# Activity                   8.795060
# Name                       3.337784
# Sex                        9.462617
# Age                       44.742991
# Injury                     0.450601
# Fatal (Y/N)                0.317089
# Time                      53.621495
# Species                   48.965287
# Investigator or Source     0.250334
# dtype: float64

# %%
mn.bar(attacks)

# %%
mn.matrix(attacks)

# %%
sorted = attacks.sort_values('Time')
mn.matrix(sorted)

# %%
sorted_age = attacks.sort_values('Age')
mn.matrix(sorted_age)

# %%
mn.heatmap(attacks)

# %%
mn.dendrogram(attacks)

# %%
attacks.dropna(subset=['Country'],how='all',inplace=True)

# %%
attacks.dropna(subset=['Fatal (Y/N)'],how='all',inplace=True)

# %%
attacks.dropna(subset=['Injury'],how='all',inplace=True)

# %%
attacks.dropna(subset=['Name'],how='all',inplace=True)

# %%
attacks.dropna(subset=['Investigator or Source'],how='all',inplace=True)

# %%
attacks.dropna(subset=['Area'],how='all',inplace=True)

# %%
attacks.dropna(subset=['Location'],how='all',inplace=True)

# %%
attacks.dropna(subset=['Activity'],how='all',inplace=True)

# %%
attacks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4770 entries, 0 to 5991
# Data columns (total 16 columns):
# Case Number               4770 non-null object
# Date                      4770 non-null object
# Year                      4770 non-null int64
# Type                      4770 non-null object
# Country                   4770 non-null object
# Area                      4770 non-null object
# Location                  4770 non-null object
# Activity                  4770 non-null object
# Name                      4770 non-null object
# Sex                       4491 non-null object
# Age                       2985 non-null object
# Injury                    4770 non-null object
# Fatal (Y/N)               4770 non-null object
# Time                      2604 non-null object
# Species                   2684 non-null object
# Investigator or Source    4770 non-null object
# dtypes: int64(1), object(15)
# memory usage: 633.5+ KB

# %%
attacks['Age'].nunique()
# Out:
# 142

# %%
attacks['Age'] = attacks['Age'].str.extract("([0-9]+)", expand=False)

# %%
attacks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4770 entries, 0 to 5991
# Data columns (total 16 columns):
# Case Number               4770 non-null object
# Date                      4770 non-null object
# Year                      4770 non-null int64
# Type                      4770 non-null object
# Country                   4770 non-null object
# Area                      4770 non-null object
# Location                  4770 non-null object
# Activity                  4770 non-null object
# Name                      4770 non-null object
# Sex                       4491 non-null object
# Age                       2960 non-null object
# Injury                    4770 non-null object
# Fatal (Y/N)               4770 non-null object
# Time                      2604 non-null object
# Species                   2684 non-null object
# Investigator or Source    4770 non-null object
# dtypes: int64(1), object(15)
# memory usage: 633.5+ KB

# %%
attacks['Age'].astype(float)
# Out:
# 0       16.0
# 1       36.0
# 2       43.0
# 3        NaN
# 4        NaN
#         ...
# 5980     NaN
# 5986     NaN
# 5987     NaN
# 5989     NaN
# 5991    15.0
# Name: Age, Length: 4770, dtype: float64

# %%
# convert column "a" of a DataFrame
attacks["Age"] = pd.to_numeric(attacks["Age"])

# %%
attacks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4770 entries, 0 to 5991
# Data columns (total 16 columns):
# Case Number               4770 non-null object
# Date                      4770 non-null object
# Year                      4770 non-null int64
# Type                      4770 non-null object
# Country                   4770 non-null object
# Area                      4770 non-null object
# Location                  4770 non-null object
# Activity                  4770 non-null object
# Name                      4770 non-null object
# Sex                       4491 non-null object
# Age                       2960 non-null float64
# Injury                    4770 non-null object
# Fatal (Y/N)               4770 non-null object
# Time                      2604 non-null object
# Species                   2684 non-null object
# Investigator or Source    4770 non-null object
# dtypes: float64(1), int64(1), object(14)
# memory usage: 633.5+ KB

# %%
mean_value=attacks['Age'].mean()
attacks['Age']=attacks['Age'].fillna(mean_value)

# %%
attacks.to_csv('attacks_cleaned.csv')

# %%
attacks = attacks.rename(columns={'Fatal (Y/N)': "Is_Fatal"})
